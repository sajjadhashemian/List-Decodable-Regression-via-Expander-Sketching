# %% [markdown]
# # Synthetic demo for ExpanderLDRRegressor
# This notebook illustrates how to instantiate the placeholder estimator and run a basic synthetic experiment.

# %%
import numpy as np
from run_synthetic_experiment import run

# %%
result = run()
print(result)
# Out:
# recovery_error=4.2454, test_mse=18.4300, n_inliers=1000
# {'config': SyntheticConfig(n_train=5000, n_test=2000, d=20, alpha=0.2, noise_std=0.1, outlier_scale=10.0, seeds=10, random_state=0, repetitions=8, buckets=200, left_degree=3, filtering_rounds=4, blocks=16, ridge=0.001, prune_eta=0.2, prune_rho=0.1), 'recovery_error': 4.245394818610437, 'test_mse': 18.42996642090177, 'n_inliers': 1000}
